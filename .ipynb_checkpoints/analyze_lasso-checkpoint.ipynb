# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.metrics import classification_report 
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.model_selection import train_test_split
import pickle as pkl

# %% [markdown]
# # analyze lasso results

# %%
covar_only = pd.read_csv("data/covar_only_result_loocv.txt", header=None)
meth_only = pd.read_csv("data/meth_only_result_loocv.txt", header=None)
meth_covar = pd.read_csv("data/meth_covar_result_loocv.txt", header=None)

# %%
true = pd.read_csv("lasso_als_binary/als_samtools_lasso_status.txt", delimiter="\t", header=None)

# %%
cnf = confusion_matrix(true, np.round(meth_only[0]))

# %%
sns.heatmap(cnf, annot=True, cmap="mako_r")
plt.xlabel("true")
plt.ylabel("prediction")
plt.show()

# %%
# print(classification_report(true, meth_covar[0]))

# %%
meth_auc = np.round(roc_auc_score(true[0], meth_only[0]), 2)
meth_covar_auc = np.round(roc_auc_score(true[0], meth_covar[0]), 2)
covar_auc = np.round(roc_auc_score(true[0], covar_only[0]), 2)

# %%
roc_auc_score(true[0], meth_only[0])
# Out:
# 0.8345618345618345

# %%
covar_auc, meth_auc, meth_covar_auc
# Out:
# (0.76, 0.83, 0.85)

# %%
np.round(meth_covar[0])
# Out:
# 0     0.0
# 1     1.0
# 2     1.0
# 3     0.0
# 4     1.0
#      ...
# 65    0.0
# 66    0.0
# 67    0.0
# 68    1.0
# 69    1.0
# Name: 0, Length: 70, dtype: float64

# %%
plt.figure(figsize=(5, 5))
fpr_mc, tpr_mc, __ = roc_curve(true[0],  meth_covar[0],  pos_label=1)
fpr_m, tpr_m, __ = roc_curve(true[0], meth_only[0])
fpr_c, tpr_c, __ = roc_curve(true[0],  covar_only[0])


plt.plot(fpr_mc, tpr_mc,  color="black", label=f"methylation + covariates, auc={meth_covar_auc}")
plt.plot(fpr_m, tpr_m, color="#196a7d", label=f"methylation only, auc={meth_auc}")
plt.plot(fpr_c, tpr_c, color="#61c2d3", label=f"covariates only, auc={covar_auc}")
plt.plot([i/10 for i in range(11)], [i/10 for i in range(11)], color="grey", linestyle='--')

plt.legend()

plt.xlabel("false positive rate")
plt.ylabel("true positive rate")

plt.show()

# %%
meth_ps = np.round(average_precision_score(true[0], meth_only), 2)
meth_covar_ps = np.round(average_precision_score(true[0], meth_covar), 2)
covar_ps = np.round(average_precision_score(true[0], covar_only), 2)

# %%
meth_ps, covar_ps, meth_covar_ps
# Out:
# (0.86, 0.79, 0.86)

# %%
plt.figure(figsize=(5, 5))

precision_mc, recall_mc, _ = precision_recall_curve(true[0],  meth_covar[0], pos_label=1)
precision_m, recall_m, __ = precision_recall_curve(true[0],  meth_only[0], pos_label=1)
precision_c, recall_c, __ = precision_recall_curve(true[0], covar_only[0], pos_label=1)


plt.plot(recall_mc, precision_mc,  color="black", label=f"methylation + covariates, auprc={meth_covar_ps}")
plt.plot(recall_m, precision_m,  color="#196a7d", label=f"methylation only, auprc={meth_ps}")
plt.plot(recall_c, precision_c, color="#61c2d3", label=f"covariates only, auprc={covar_ps}")

plt.legend() 
plt.xlabel("recall")
plt.ylabel("precision")

plt.show()

# %% [markdown]
# # als only

# %%
als_covariates_cleaned = covariates_no_missing.drop_duplicates(subset=["sample"])

# %%
covariates_to_keep = ["sample_num", "sample", "ALSFRS-R Slope", "Sex", "age", "Ethnicity", "pg/ml"]
selected_covariates = als_covariates_cleaned[covariates_to_keep]

selected_covariates = selected_covariates.dropna()

# %%
selected_covariates["sample"].nunique()

# %%
keep = selected_covariates["sample_num"]
prop_cleaned = prop[keep].dropna().T

# %%
prop_cleaned.shape

# %%
encoder = OneHotEncoder(handle_unknown="ignore")

sex = pd.DataFrame(encoder.fit_transform(selected_covariates["Sex"].values.reshape(-1,1)).toarray())
ethnicity = pd.DataFrame(encoder.fit_transform(selected_covariates["Ethnicity"].values.reshape(-1,1)).toarray())
age = pd.DataFrame(selected_covariates["age"].values)
concentration = pd.DataFrame(selected_covariates["pg/ml"].values)

# %%
X = pd.concat([sex, ethnicity, age, concentration, prop_cleaned.reset_index(drop=True)], axis=1).values
# X = pd.concat([sex, ethnicity, age, prop_cleaned.reset_index(drop=True)], axis=1).values

pd.DataFrame(X).to_csv("slope_lasso_input_covariates_feb24.txt", sep="\t", index=False, header=None)

# %%
Y = selected_covariates["ALSFRS-R Slope"]

pd.DataFrame(Y).to_csv("slope_lasso_status_feb24.txt", sep="\t", index=False, header=None)

# %%
X.shape, Y.shape

# %% [markdown]
# ## analyze

# %%
alsfrs_meth_covar = pd.read_csv("fvc_meth_covar_10_feb24.txt", header=None)
alsfrs_meth_covar.columns = ["predicted"]
alsfrs_meth_covar["type"] = "full model"

# %%
alsfrs_covs = pd.read_csv("fvc_covar_only_10_feb24.txt", header=None)
alsfrs_covs.columns = ["predicted"]
alsfrs_covs["type"] = "covariate only"

# %%
true = pd.read_csv("FVC_lasso_status_feb24.txt", delimiter="\t", header=None)

# %%
alsfrs_meth_covar["true"] = true[0].values
alsfrs_covs["true"] = true[0].values

# %%
combined = pd.concat([alsfrs_covs, alsfrs_meth_covar ])

# %%
sns.lmplot(x="true", y="predicted", hue="type", data=combined[combined["type"] == "covariate only"],
           palette=sns.color_palette(["green"]))
plt.xlabel("true FVC ")
plt.ylabel("predicted FVC")
# plt.xlim(0, 12)
# plt.ylim(0, 12)
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(alsfrs_covs["predicted"], alsfrs_covs["true"])
slope, intercept, r_value*r_value, p_value, std_err

# %%
# sns.lmplot(x="true", y="predicted", hue="type", data=combined)
# plt.xlabel("true ALS-FRS slope")
# plt.ylabel("predicted ALS-FRS slope")
# plt.xlim(0, 2)
# plt.ylim(0, 2)
# plt.show()

# %%
r2_score(alsfrs_meth_covar["true"], alsfrs_meth_covar["predicted"])

# %%
mean_squared_error(alsfrs_meth_covar["true"], alsfrs_meth_covar["predicted"])

# %% [markdown]
# # betas

# %%
methylation_input = pd.read_csv("lasso_als_binary/als_lasso_input_covariates.txt", delimiter="\t", header=None)
als_status = pd.read_csv("lasso_als_binary/als_lasso_status.txt", delimiter="\t", header=None)

# %%
methylation_input = methylation_input.drop([1, 2, 3, 4, 5], axis=1)

# %%
methylation_input
methylation_input["als_status"] = als_status[0].values

# %%
weights = pd.read_csv("lasso_als_binary/meth_covar_nocv_all_weights", header=None)
weights["abs weights"] = abs(weights[0])

# %%
top_weights = weights.sort_values(by="abs weights", ascending=False).index
top_weight_values = weights.sort_values(by="abs weights", ascending=False)[0].values

# %%
w = 5

sns.violinplot(x=als_status[0].values, 
            y=methylation_input[top_weights[w]].values, palette=sns.color_palette(["#196a7d", "#61c2d3"]))
plt.xlabel("ALS disease status")
plt.ylabel("methylation proportion")
plt.title(f"weight = {np.round(top_weight_values[w], 4)}")
plt.show()

# %%
sample_methylation = pd.read_csv("lasso_als_binary/als_lasso_input_covariates.txt", delimiter="\t", header=None).iloc[:, 9:].T
sites = pd.read_csv("sites_keep.csv", header=None)
weights = pd.read_csv("lasso_als_binary/meth_covar_nocv_all_weights", header=None)

# %%
sample_methylation[["chr", "start", "end"]] = sites.values

# %%
sample_methylation["weight"] = weights.iloc[4:,0 ].values
sample_methylation["abs weight"] = abs(weights.iloc[4:,0 ].values)

# %%
sns.histplot(x="abs weight", data=sample_methylation, bins=50, color="#61c2d3")
plt.yscale("log")
plt.show()

# %%
nonzero_weights = sample_methylation[sample_methylation["abs weight"] > 0]

# %%
len(nonzero_weights)
# Out:
# 128

# %%
order = [f"chr{i}" for i in range(1, 23)] + ["chrX"]

sns.countplot(x="chr", data=nonzero_weights, order=order, color="#196a7d")
plt.xticks(rotation=45)
plt.show()

# %%
sample_methylation["weight_category"] = np.where(sample_methylation["abs weight"] > 0, "non-zero", "zero")

# %%
prop_df = sample_methylation.groupby("chr")["weight_category"].value_counts(normalize=True).reset_index(name="prop")

# %%
order = [f"chr{i}" for i in range(1, 23)] + ["chrX"]

sns.barplot(x="chr", y="prop", data=prop_df[prop_df["weight_category"] == "non-zero"], 
            color="#0096ae", order=order)
plt.xticks(rotation=45)
plt.ylabel("proportion of total sites")
plt.show()

# %%
sample_methylation[["chr", "start", "end", "weight", "abs weight"]].to_csv("sample_methylation.bed", 
                                                                           sep="\t", header=None, index=False)

# %%
tissues = pd.read_csv("sample_methylation_gene.bed", delimiter="\t", header=None)

# %%
# tissues = tissues[[0, 1, 2, 3, 4, 22]].drop_duplicates()

# %%
nonzero_tissues = tissues[tissues[4] > 0]

# %%
tissues.sort_values(by=4, ascending=False).drop_duplicates(subset=[0, 1, 2, 3, 4])[8].value_counts()
# Out:
# .                  636
# TBX1                36
# ENSG00000260473     26
# DTX1                20
# LYL1                19
#                   ...
# RPRD1B               1
# RAD54L2              1
# SLC44A5              1
# LINC01800            1
# SLCO2A1              1
# Name: 8, Length: 1724, dtype: int64

# %%
for t in nonzero_tissues.sort_values(by=4, ascending=False).drop_duplicates(subset=[0, 1, 2, 3, 4])[8].unique(): 
    if not t == ".":
        print(t)
# Out:
# GUCD1
# RABL3
# SCARF2
# SGMS1
# MEX3C
# ESYT3
# LINC01122
# CLPP
# MPPE1
# ADARB1
# CERS6
# APBB1IP
# ZFAND3-DT
# PHACTR4
# PLK4
# ERFE
# ARHGAP27P1-BPTFP1-KPNA2P3
# STPG1
# RNF170
# PYURF
# POLR2F
# CDH15
# CACNA1I
# ZMIZ1
# ZFPM1
# NBAS
# GSG1L
# SPC24
# LTBP4
# FIGNL2
# DNAJB6
# JAK2
# ZNRF2P1
# SMG1P2
# MECOM
# BRI3
# SP9
# LINC00840
# SKI
# GGA2
# DNAH10
# PROX1-AS1
# PPP5D1P
# VAV3
# KDM5B
# LINC02601
# TPM4
# RCN3
# EFNB2
# CEP250
# ESYT2
# NR2F2-AS1
# SLC8B1
# PLCB2
# FANCA
# SEPTIN9
# SLC29A3
# GALNS
# MYH9
# CDH23
# ZC3HAV1L
# SRC
# OSBPL3
# PRR5L
# CMTM7
# ENSG00000256982
# PLEKHM1P1
# LINC01891
# LINC02324
# ENSG00000272578
# ENSG00000284633
# PAK4
# MCF2L2
# ADGRL1
# ODAD3
# TTLL8
# TANC1
# HIRA
# NCOR2
# ARID3A
# PARD6G-AS1
# ADCK1
# ZNF319
# LIPE-AS1
# C17orf64
# PDE8A
# ZFX
# LINC01643
# MPRIP
# HOXD3
# AHDC1
# DNM2
# ENSG00000268555
# TMEM53
# PRKCH
# L1CAM

# %% [markdown]
# # wgbs

# %%
df = pd.read_csv("../../als/als_idt_tims_500.txt", delimiter="\t", header=None)

# %%
meth = df.iloc[:, 0::2]
depth = df.iloc[:, 1::2]

# %%
prop = meth.values/depth.values

# %%
prop.fillna(prop.median()).to_csv("old_als_500_prop.txt", sep="\t", header=None, index=False)

# %%
prop = pd.DataFrame(prop)

# %%
prop.fillna(prop.median())
